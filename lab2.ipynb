# %%
import os
import pathlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pf=pd.read_csv("C:/Users/DS3/Downloads/mpg_raw(1).csv")

# %%
pf.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
plt.hist(pf['acceleration'])
# Out:
# (array([ 6., 15., 50., 86., 92., 80., 45., 13.,  7.,  4.]),
#  array([ 8.  ,  9.68, 11.36, 13.04, 14.72, 16.4 , 18.08, 19.76, 21.44,
#         23.12, 24.8 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(x=pf['cylinders'],y=pf['model_year'])

# %%
sns.countplot(x='mpg',data=pf)
# Out:
# <Axes: xlabel='mpg', ylabel='count'>

# %%
sns.pointplot(x='origin',y='cylinders',data=pf)
# Out:
# <Axes: xlabel='origin', ylabel='cylinders'>
